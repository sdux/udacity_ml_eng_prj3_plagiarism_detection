# %% [markdown]
# # Plagiarism Detection Model
#
# Now that you've created training and test data, you are ready to define and train a model. Your goal in this notebook, will be to train a binary classification model that learns to label an answer file as either plagiarized or not, based on the features you provide the model.
#
# This task will be broken down into a few discrete steps:
#
# * Upload your data to S3.
# * Define a binary classification model and a training script.
# * Train your model and deploy it.
# * Evaluate your deployed classifier and answer some questions about your approach.
#
# To complete this notebook, you'll have to complete all given exercises and answer all the questions in this notebook.
# > All your tasks will be clearly labeled **EXERCISE** and questions as **QUESTION**.
#
# It will be up to you to explore different classification models and decide on a model that gives you the best performance for this dataset.
#
# ---

# %% [markdown]
# ## Load Data to S3
#
# In the last notebook, you should have created two files: a `training.csv` and `test.csv` file with the features and class labels for the given corpus of plagiarized/non-plagiarized text data.
#
# >The below cells load in some AWS SageMaker libraries and creates a default bucket. After creating this bucket, you can upload your locally stored data to S3.
#
# Save your train and test `.csv` feature files, locally. To do this you can run the second notebook "2_Plagiarism_Feature_Engineering" in SageMaker or you can manually upload your files to this notebook using the upload icon in Jupyter Lab. Then you can upload local files to S3 by using `sagemaker_session.upload_data` and pointing directly to where the training data is saved.

# %%
import pandas as pd
import boto3
import sagemaker

# %%
"""
DON'T MODIFY ANYTHING IN THIS CELL THAT IS BELOW THIS LINE
"""
# session and role
sagemaker_session = sagemaker.Session()
role = sagemaker.get_execution_role()

# create an S3 bucket

bucket = sagemaker_session.default_bucket()

# %% [markdown]
# ## EXERCISE: Upload your training data to S3
#
# Specify the `data_dir` where you've saved your `train.csv` file. Decide on a descriptive `prefix` that defines where your data will be uploaded in the default S3 bucket. Finally, create a pointer to your training data by calling `sagemaker_session.upload_data` and passing in the required parameters. It may help to look at the [Session documentation](https://sagemaker.readthedocs.io/en/stable/session.html#sagemaker.session.Session.upload_data) or previous SageMaker code examples.
#
# You are expected to upload your entire directory. Later, the training script will only access the `train.csv` file.

# %%
# should be the name of directory you created to save your features data
data_dir = 'plagiarism_data'

# set prefix, a descriptive name for a directory  
prefix = 'plagiarism_exercise'

# upload all data to S3

#sagemaker_session.upload_data(s3://{bucket}/{prefix}/{data_dir}/)
#path=data_dir, bucket=bucket, key_prefix=prefix
print('Bucket: ',bucket)
print('path: ',data_dir)

input_data = sagemaker_session.upload_data(path=data_dir, bucket=bucket, key_prefix=prefix)
print(input_data)
# Out:
# Bucket:  sagemaker-us-west-2-405691024166
# path:  plagiarism_data
# s3://sagemaker-us-west-2-405691024166/plagiarism_exercise

# %% [markdown]
# ### Test cell
#
# Test that your data has been successfully uploaded. The below cell prints out the items in your S3 bucket and will throw an error if it is empty. You should see the contents of your `data_dir` and perhaps some checkpoints. If you see any other files listed, then you may have some old model files that you can delete via the S3 console (though, additional files shouldn't affect the performance of model developed in this notebook).

# %%
"""
DON'T MODIFY ANYTHING IN THIS CELL THAT IS BELOW THIS LINE
"""
# confirm that data is in S3 bucket
empty_check = []
for obj in boto3.resource('s3').Bucket(bucket).objects.all():
    empty_check.append(obj.key)
    print(obj.key)

assert len(empty_check) !=0, 'S3 bucket is empty.'
print('Test passed!')
# Out:
# boston-xgboost-HL/output/xgboost-2021-06-29-16-16-42-154/output/model.tar.gz
# boston-xgboost-HL/test.csv
# boston-xgboost-HL/train.csv
# boston-xgboost-HL/validation.csv
# counties/kmeans-2021-07-07-20-55-56-625/output/model.tar.gz
# counties/kmeans-2021-07-07-20-55-56-625/profiler-output/framework/training_job_end.ts
# counties/kmeans-2021-07-07-20-55-56-625/profiler-output/system/incremental/2021070720/1625691480.algo-1.json
# counties/kmeans-2021-07-07-20-55-56-625/profiler-output/system/incremental/2021070720/1625691540.algo-1.json
# counties/kmeans-2021-07-07-20-55-56-625/profiler-output/system/training_job_end.ts
# counties/kmeans-2021-07-07-20-55-56-625/rule-output/ProfilerReport-1625691356/profiler-output/profiler-report.html
# counties/kmeans-2021-07-07-20-55-56-625/rule-output/ProfilerReport-1625691356/profiler-output/profiler-report.ipynb
# counties/kmeans-2021-07-07-20-55-56-625/rule-output/ProfilerReport-1625691356/profiler-output/profiler-reports/BatchSize.json
# counties/kmeans-2021-07-07-20-55-56-625/rule-output/ProfilerReport-1625691356/profiler-output/profiler-reports/CPUBottleneck.json
# counties/kmeans-2021-07-07-20-55-56-625/rule-output/ProfilerReport-1625691356/profiler-output/profiler-reports/Dataloader.json
# counties/kmeans-2021-07-07-20-55-56-625/rule-output/ProfilerReport-1625691356/profiler-output/profiler-reports/GPUMemoryIncrease.json
# counties/kmeans-2021-07-07-20-55-56-625/rule-output/ProfilerReport-1625691356/profiler-output/profiler-reports/IOBottleneck.json
# counties/kmeans-2021-07-07-20-55-56-625/rule-output/ProfilerReport-1625691356/profiler-output/profiler-reports/LoadBalancing.json
# counties/kmeans-2021-07-07-20-55-56-625/rule-output/ProfilerReport-1625691356/profiler-output/profiler-reports/LowGPUUtilization.json
# counties/kmeans-2021-07-07-20-55-56-625/rule-output/ProfilerReport-1625691356/profiler-output/profiler-reports/MaxInitializationTime.json
# counties/kmeans-2021-07-07-20-55-56-625/rule-output/ProfilerReport-1625691356/profiler-output/profiler-reports/OverallFrameworkMetrics.json
# counties/kmeans-2021-07-07-20-55-56-625/rule-output/ProfilerReport-1625691356/profiler-output/profiler-reports/OverallSystemUsage.json
# counties/kmeans-2021-07-07-20-55-56-625/rule-output/ProfilerReport-1625691356/profiler-output/profiler-reports/StepOutlier.json
# counties/pca-2021-07-05-20-17-49-387/output/model.tar.gz
# counties/pca-2021-07-05-20-17-49-387/profiler-output/framework/training_job_end.ts
# counties/pca-2021-07-05-20-17-49-387/profiler-output/system/incremental/2021070520/1625516400.algo-1.json
# counties/pca-2021-07-05-20-17-49-387/profiler-output/system/incremental/2021070520/1625516460.algo-1.json
# counties/pca-2021-07-05-20-17-49-387/profiler-output/system/training_job_end.ts
# counties/pca-2021-07-05-20-17-49-387/rule-output/ProfilerReport-1625516269/profiler-output/profiler-report.html
# counties/pca-2021-07-05-20-17-49-387/rule-output/ProfilerReport-1625516269/profiler-output/profiler-report.ipynb
# counties/pca-2021-07-05-20-17-49-387/rule-output/ProfilerReport-1625516269/profiler-output/profiler-reports/BatchSize.json
# counties/pca-2021-07-05-20-17-49-387/rule-output/ProfilerReport-1625516269/profiler-output/profiler-reports/CPUBottleneck.json
# counties/pca-2021-07-05-20-17-49-387/rule-output/ProfilerReport-1625516269/profiler-output/profiler-reports/Dataloader.json
# counties/pca-2021-07-05-20-17-49-387/rule-output/ProfilerReport-1625516269/profiler-output/profiler-reports/GPUMemoryIncrease.json
# counties/pca-2021-07-05-20-17-49-387/rule-output/ProfilerReport-1625516269/profiler-output/profiler-reports/IOBottleneck.json
# counties/pca-2021-07-05-20-17-49-387/rule-output/ProfilerReport-1625516269/profiler-output/profiler-reports/LoadBalancing.json
# counties/pca-2021-07-05-20-17-49-387/rule-output/ProfilerReport-1625516269/profiler-output/profiler-reports/LowGPUUtilization.json
# counties/pca-2021-07-05-20-17-49-387/rule-output/ProfilerReport-1625516269/profiler-output/profiler-reports/MaxInitializationTime.json
# counties/pca-2021-07-05-20-17-49-387/rule-output/ProfilerReport-1625516269/profiler-output/profiler-reports/OverallFrameworkMetrics.json
# counties/pca-2021-07-05-20-17-49-387/rule-output/ProfilerReport-1625516269/profiler-output/profiler-reports/OverallSystemUsage.json
# counties/pca-2021-07-05-20-17-49-387/rule-output/ProfilerReport-1625516269/profiler-output/profiler-reports/StepOutlier.json
# counties/pca-2021-07-06-00-19-44-965/output/model.tar.gz
# counties/pca-2021-07-06-00-19-44-965/profiler-output/framework/training_job_end.ts
# counties/pca-2021-07-06-00-19-44-965/profiler-output/system/incremental/2021070600/1625530920.algo-1.json
# counties/pca-2021-07-06-00-19-44-965/profiler-output/system/incremental/2021070600/1625530980.algo-1.json
# counties/pca-2021-07-06-00-19-44-965/profiler-output/system/training_job_end.ts
# counties/pca-2021-07-06-00-19-44-965/rule-output/ProfilerReport-1625530784/profiler-output/profiler-report.html
# counties/pca-2021-07-06-00-19-44-965/rule-output/ProfilerReport-1625530784/profiler-output/profiler-report.ipynb
# counties/pca-2021-07-06-00-19-44-965/rule-output/ProfilerReport-1625530784/profiler-output/profiler-reports/BatchSize.json
# counties/pca-2021-07-06-00-19-44-965/rule-output/ProfilerReport-1625530784/profiler-output/profiler-reports/CPUBottleneck.json
# counties/pca-2021-07-06-00-19-44-965/rule-output/ProfilerReport-1625530784/profiler-output/profiler-reports/Dataloader.json
# counties/pca-2021-07-06-00-19-44-965/rule-output/ProfilerReport-1625530784/profiler-output/profiler-reports/GPUMemoryIncrease.json
# counties/pca-2021-07-06-00-19-44-965/rule-output/ProfilerReport-1625530784/profiler-output/profiler-reports/IOBottleneck.json
# counties/pca-2021-07-06-00-19-44-965/rule-output/ProfilerReport-1625530784/profiler-output/profiler-reports/LoadBalancing.json
# counties/pca-2021-07-06-00-19-44-965/rule-output/ProfilerReport-1625530784/profiler-output/profiler-reports/LowGPUUtilization.json
# counties/pca-2021-07-06-00-19-44-965/rule-output/ProfilerReport-1625530784/profiler-output/profiler-reports/MaxInitializationTime.json
# counties/pca-2021-07-06-00-19-44-965/rule-output/ProfilerReport-1625530784/profiler-output/profiler-reports/OverallFrameworkMetrics.json
# counties/pca-2021-07-06-00-19-44-965/rule-output/ProfilerReport-1625530784/profiler-output/profiler-reports/OverallSystemUsage.json
# counties/pca-2021-07-06-00-19-44-965/rule-output/ProfilerReport-1625530784/profiler-output/profiler-reports/StepOutlier.json
# counties/pca-2021-07-07-15-52-58-342/output/model.tar.gz
# counties/pca-2021-07-07-15-52-58-342/profiler-output/framework/training_job_end.ts
# counties/pca-2021-07-07-15-52-58-342/profiler-output/system/incremental/2021070715/1625673300.algo-1.json
# counties/pca-2021-07-07-15-52-58-342/profiler-output/system/incremental/2021070715/1625673360.algo-1.json
# counties/pca-2021-07-07-15-52-58-342/profiler-output/system/training_job_end.ts
# counties/pca-2021-07-07-15-52-58-342/rule-output/ProfilerReport-1625673178/profiler-output/profiler-report.html
# counties/pca-2021-07-07-15-52-58-342/rule-output/ProfilerReport-1625673178/profiler-output/profiler-report.ipynb
# counties/pca-2021-07-07-15-52-58-342/rule-output/ProfilerReport-1625673178/profiler-output/profiler-reports/BatchSize.json
# counties/pca-2021-07-07-15-52-58-342/rule-output/ProfilerReport-1625673178/profiler-output/profiler-reports/CPUBottleneck.json
# counties/pca-2021-07-07-15-52-58-342/rule-output/ProfilerReport-1625673178/profiler-output/profiler-reports/Dataloader.json
# counties/pca-2021-07-07-15-52-58-342/rule-output/ProfilerReport-1625673178/profiler-output/profiler-reports/GPUMemoryIncrease.json
# counties/pca-2021-07-07-15-52-58-342/rule-output/ProfilerReport-1625673178/profiler-output/profiler-reports/IOBottleneck.json
# counties/pca-2021-07-07-15-52-58-342/rule-output/ProfilerReport-1625673178/profiler-output/profiler-reports/LoadBalancing.json
# counties/pca-2021-07-07-15-52-58-342/rule-output/ProfilerReport-1625673178/profiler-output/profiler-reports/LowGPUUtilization.json
# counties/pca-2021-07-07-15-52-58-342/rule-output/ProfilerReport-1625673178/profiler-output/profiler-reports/MaxInitializationTime.json
# counties/pca-2021-07-07-15-52-58-342/rule-output/ProfilerReport-1625673178/profiler-output/profiler-reports/OverallFrameworkMetrics.json
# counties/pca-2021-07-07-15-52-58-342/rule-output/ProfilerReport-1625673178/profiler-output/profiler-reports/OverallSystemUsage.json
# counties/pca-2021-07-07-15-52-58-342/rule-output/ProfilerReport-1625673178/profiler-output/profiler-reports/StepOutlier.json
# creditcard/linear-learner-2021-07-08-21-10-46-154/output/model.tar.gz
# creditcard/linear-learner-2021-07-08-21-10-46-154/profiler-output/framework/training_job_end.ts
# creditcard/linear-learner-2021-07-08-21-10-46-154/profiler-output/system/incremental/2021070821/1625778780.algo-1.json
# creditcard/linear-learner-2021-07-08-21-10-46-154/profiler-output/system/incremental/2021070821/1625778840.algo-1.json
# creditcard/linear-learner-2021-07-08-21-10-46-154/profiler-output/system/incremental/2021070821/1625778900.algo-1.json
# creditcard/linear-learner-2021-07-08-21-10-46-154/profiler-output/system/incremental/2021070821/1625778960.algo-1.json
# creditcard/linear-learner-2021-07-08-21-10-46-154/profiler-output/system/training_job_end.ts
# creditcard/linear-learner-2021-07-08-21-10-46-154/rule-output/ProfilerReport-1625778646/profiler-output/profiler-report.html
# creditcard/linear-learner-2021-07-08-21-10-46-154/rule-output/ProfilerReport-1625778646/profiler-output/profiler-report.ipynb
# creditcard/linear-learner-2021-07-08-21-10-46-154/rule-output/ProfilerReport-1625778646/profiler-output/profiler-reports/BatchSize.json
# creditcard/linear-learner-2021-07-08-21-10-46-154/rule-output/ProfilerReport-1625778646/profiler-output/profiler-reports/CPUBottleneck.json
# creditcard/linear-learner-2021-07-08-21-10-46-154/rule-output/ProfilerReport-1625778646/profiler-output/profiler-reports/Dataloader.json
# creditcard/linear-learner-2021-07-08-21-10-46-154/rule-output/ProfilerReport-1625778646/profiler-output/profiler-reports/GPUMemoryIncrease.json
# creditcard/linear-learner-2021-07-08-21-10-46-154/rule-output/ProfilerReport-1625778646/profiler-output/profiler-reports/IOBottleneck.json
# creditcard/linear-learner-2021-07-08-21-10-46-154/rule-output/ProfilerReport-1625778646/profiler-output/profiler-reports/LoadBalancing.json
# creditcard/linear-learner-2021-07-08-21-10-46-154/rule-output/ProfilerReport-1625778646/profiler-output/profiler-reports/LowGPUUtilization.json
# creditcard/linear-learner-2021-07-08-21-10-46-154/rule-output/ProfilerReport-1625778646/profiler-output/profiler-reports/MaxInitializationTime.json
# creditcard/linear-learner-2021-07-08-21-10-46-154/rule-output/ProfilerReport-1625778646/profiler-output/profiler-reports/OverallFrameworkMetrics.json
# creditcard/linear-learner-2021-07-08-21-10-46-154/rule-output/ProfilerReport-1625778646/profiler-output/profiler-reports/OverallSystemUsage.json
# creditcard/linear-learner-2021-07-08-21-10-46-154/rule-output/ProfilerReport-1625778646/profiler-output/profiler-reports/StepOutlier.json
# creditcard/linear-learner-2021-07-09-02-14-45-962/output/model.tar.gz
# creditcard/linear-learner-2021-07-09-02-14-45-962/profiler-output/framework/training_job_end.ts
# creditcard/linear-learner-2021-07-09-02-14-45-962/profiler-output/system/incremental/2021070902/1625797020.algo-1.json
# creditcard/linear-learner-2021-07-09-02-14-45-962/profiler-output/system/incremental/2021070902/1625797080.algo-1.json
# creditcard/linear-learner-2021-07-09-02-14-45-962/profiler-output/system/incremental/2021070902/1625797140.algo-1.json
# creditcard/linear-learner-2021-07-09-02-14-45-962/profiler-output/system/incremental/2021070902/1625797200.algo-1.json
# creditcard/linear-learner-2021-07-09-02-14-45-962/profiler-output/system/training_job_end.ts
# creditcard/linear-learner-2021-07-09-02-14-45-962/rule-output/ProfilerReport-1625796885/profiler-output/profiler-report.html
# creditcard/linear-learner-2021-07-09-02-14-45-962/rule-output/ProfilerReport-1625796885/profiler-output/profiler-report.ipynb
# creditcard/linear-learner-2021-07-09-02-14-45-962/rule-output/ProfilerReport-1625796885/profiler-output/profiler-reports/BatchSize.json
# creditcard/linear-learner-2021-07-09-02-14-45-962/rule-output/ProfilerReport-1625796885/profiler-output/profiler-reports/CPUBottleneck.json
# creditcard/linear-learner-2021-07-09-02-14-45-962/rule-output/ProfilerReport-1625796885/profiler-output/profiler-reports/Dataloader.json
# creditcard/linear-learner-2021-07-09-02-14-45-962/rule-output/ProfilerReport-1625796885/profiler-output/profiler-reports/GPUMemoryIncrease.json
# creditcard/linear-learner-2021-07-09-02-14-45-962/rule-output/ProfilerReport-1625796885/profiler-output/profiler-reports/IOBottleneck.json
# creditcard/linear-learner-2021-07-09-02-14-45-962/rule-output/ProfilerReport-1625796885/profiler-output/profiler-reports/LoadBalancing.json
# creditcard/linear-learner-2021-07-09-02-14-45-962/rule-output/ProfilerReport-1625796885/profiler-output/profiler-reports/LowGPUUtilization.json
# creditcard/linear-learner-2021-07-09-02-14-45-962/rule-output/ProfilerReport-1625796885/profiler-output/profiler-reports/MaxInitializationTime.json
# creditcard/linear-learner-2021-07-09-02-14-45-962/rule-output/ProfilerReport-1625796885/profiler-output/profiler-reports/OverallFrameworkMetrics.json
# creditcard/linear-learner-2021-07-09-02-14-45-962/rule-output/ProfilerReport-1625796885/profiler-output/profiler-reports/OverallSystemUsage.json
# creditcard/linear-learner-2021-07-09-02-14-45-962/rule-output/ProfilerReport-1625796885/profiler-output/profiler-reports/StepOutlier.json
# deepar-energy-consumption/output/forecasting-deepar-2021-07-19-17-19-40-096/output/model.tar.gz
# deepar-energy-consumption/output/forecasting-deepar-2021-07-19-17-19-40-096/profiler-output/framework/training_job_end.ts
# deepar-energy-consumption/output/forecasting-deepar-2021-07-19-17-19-40-096/profiler-output/system/incremental/2021071917/1626715320.algo-1.json
# deepar-energy-consumption/output/forecasting-deepar-2021-07-19-17-19-40-096/profiler-output/system/incremental/2021071917/1626715380.algo-1.json
# deepar-energy-consumption/output/forecasting-deepar-2021-07-19-17-19-40-096/profiler-output/system/incremental/2021071917/1626715440.algo-1.json
# deepar-energy-consumption/output/forecasting-deepar-2021-07-19-17-19-40-096/profiler-output/system/incremental/2021071917/1626715500.algo-1.json
# deepar-energy-consumption/output/forecasting-deepar-2021-07-19-17-19-40-096/profiler-output/system/training_job_end.ts
# deepar-energy-consumption/output/forecasting-deepar-2021-07-19-17-19-40-096/rule-output/ProfilerReport-1626715180/profiler-output/profiler-report.html
# deepar-energy-consumption/output/forecasting-deepar-2021-07-19-17-19-40-096/rule-output/ProfilerReport-1626715180/profiler-output/profiler-report.ipynb
# deepar-energy-consumption/output/forecasting-deepar-2021-07-19-17-19-40-096/rule-output/ProfilerReport-1626715180/profiler-output/profiler-reports/BatchSize.json
# deepar-energy-consumption/output/forecasting-deepar-2021-07-19-17-19-40-096/rule-output/ProfilerReport-1626715180/profiler-output/profiler-reports/CPUBottleneck.json
# deepar-energy-consumption/output/forecasting-deepar-2021-07-19-17-19-40-096/rule-output/ProfilerReport-1626715180/profiler-output/profiler-reports/Dataloader.json
# deepar-energy-consumption/output/forecasting-deepar-2021-07-19-17-19-40-096/rule-output/ProfilerReport-1626715180/profiler-output/profiler-reports/GPUMemoryIncrease.json
# deepar-energy-consumption/output/forecasting-deepar-2021-07-19-17-19-40-096/rule-output/ProfilerReport-1626715180/profiler-output/profiler-reports/IOBottleneck.json
# deepar-energy-consumption/output/forecasting-deepar-2021-07-19-17-19-40-096/rule-output/ProfilerReport-1626715180/profiler-output/profiler-reports/LoadBalancing.json
# deepar-energy-consumption/output/forecasting-deepar-2021-07-19-17-19-40-096/rule-output/ProfilerReport-1626715180/profiler-output/profiler-reports/LowGPUUtilization.json
# deepar-energy-consumption/output/forecasting-deepar-2021-07-19-17-19-40-096/rule-output/ProfilerReport-1626715180/profiler-output/profiler-reports/MaxInitializationTime.json
# deepar-energy-consumption/output/forecasting-deepar-2021-07-19-17-19-40-096/rule-output/ProfilerReport-1626715180/profiler-output/profiler-reports/OverallFrameworkMetrics.json
# deepar-energy-consumption/output/forecasting-deepar-2021-07-19-17-19-40-096/rule-output/ProfilerReport-1626715180/profiler-output/profiler-reports/OverallSystemUsage.json
# deepar-energy-consumption/output/forecasting-deepar-2021-07-19-17-19-40-096/rule-output/ProfilerReport-1626715180/profiler-output/profiler-reports/StepOutlier.json
# deepar-energy-consumption/test/test.json
# deepar-energy-consumption/train/train.json
# fraud_model/linear-learner-2021-07-08-18-04-52-586/profiler-output/system/incremental/2021070818/1625767620.algo-1.json
# fraud_model/linear-learner-2021-07-08-18-04-52-586/profiler-output/system/incremental/2021070818/1625767680.algo-1.json
# fraud_model/linear-learner-2021-07-08-18-04-52-586/rule-output/ProfilerReport-1625767492/profiler-output/profiler-report.html
# fraud_model/linear-learner-2021-07-08-18-04-52-586/rule-output/ProfilerReport-1625767492/profiler-output/profiler-report.ipynb
# fraud_model/linear-learner-2021-07-08-18-04-52-586/rule-output/ProfilerReport-1625767492/profiler-output/profiler-reports/BatchSize.json
# fraud_model/linear-learner-2021-07-08-18-04-52-586/rule-output/ProfilerReport-1625767492/profiler-output/profiler-reports/CPUBottleneck.json
# fraud_model/linear-learner-2021-07-08-18-04-52-586/rule-output/ProfilerReport-1625767492/profiler-output/profiler-reports/Dataloader.json
# fraud_model/linear-learner-2021-07-08-18-04-52-586/rule-output/ProfilerReport-1625767492/profiler-output/profiler-reports/GPUMemoryIncrease.json
# fraud_model/linear-learner-2021-07-08-18-04-52-586/rule-output/ProfilerReport-1625767492/profiler-output/profiler-reports/IOBottleneck.json
# fraud_model/linear-learner-2021-07-08-18-04-52-586/rule-output/ProfilerReport-1625767492/profiler-output/profiler-reports/LoadBalancing.json
# fraud_model/linear-learner-2021-07-08-18-04-52-586/rule-output/ProfilerReport-1625767492/profiler-output/profiler-reports/LowGPUUtilization.json
# fraud_model/linear-learner-2021-07-08-18-04-52-586/rule-output/ProfilerReport-1625767492/profiler-output/profiler-reports/MaxInitializationTime.json
# fraud_model/linear-learner-2021-07-08-18-04-52-586/rule-output/ProfilerReport-1625767492/profiler-output/profiler-reports/OverallFrameworkMetrics.json
# fraud_model/linear-learner-2021-07-08-18-04-52-586/rule-output/ProfilerReport-1625767492/profiler-output/profiler-reports/OverallSystemUsage.json
# fraud_model/linear-learner-2021-07-08-18-04-52-586/rule-output/ProfilerReport-1625767492/profiler-output/profiler-reports/StepOutlier.json
# fraud_model/linear-learner-2021-07-08-18-14-48-909/profiler-output/system/incremental/2021070818/1625768220.algo-1.json
# fraud_model/linear-learner-2021-07-08-18-14-48-909/profiler-output/system/incremental/2021070818/1625768280.algo-1.json
# fraud_model/linear-learner-2021-07-08-18-15-26-697/output/model.tar.gz
# fraud_model/linear-learner-2021-07-08-18-15-26-697/profiler-output/framework/training_job_end.ts
# fraud_model/linear-learner-2021-07-08-18-15-26-697/profiler-output/system/incremental/2021070818/1625768280.algo-1.json
# fraud_model/linear-learner-2021-07-08-18-15-26-697/profiler-output/system/incremental/2021070818/1625768340.algo-1.json
# fraud_model/linear-learner-2021-07-08-18-15-26-697/profiler-output/system/incremental/2021070818/1625768400.algo-1.json
# fraud_model/linear-learner-2021-07-08-18-15-26-697/profiler-output/system/incremental/2021070818/1625768460.algo-1.json
# fraud_model/linear-learner-2021-07-08-18-15-26-697/profiler-output/system/training_job_end.ts
# fraud_model/linear-learner-2021-07-08-18-15-26-697/rule-output/ProfilerReport-1625768126/profiler-output/profiler-report.html
# fraud_model/linear-learner-2021-07-08-18-15-26-697/rule-output/ProfilerReport-1625768126/profiler-output/profiler-report.ipynb
# fraud_model/linear-learner-2021-07-08-18-15-26-697/rule-output/ProfilerReport-1625768126/profiler-output/profiler-reports/BatchSize.json
# fraud_model/linear-learner-2021-07-08-18-15-26-697/rule-output/ProfilerReport-1625768126/profiler-output/profiler-reports/CPUBottleneck.json
# fraud_model/linear-learner-2021-07-08-18-15-26-697/rule-output/ProfilerReport-1625768126/profiler-output/profiler-reports/Dataloader.json
# fraud_model/linear-learner-2021-07-08-18-15-26-697/rule-output/ProfilerReport-1625768126/profiler-output/profiler-reports/GPUMemoryIncrease.json
# fraud_model/linear-learner-2021-07-08-18-15-26-697/rule-output/ProfilerReport-1625768126/profiler-output/profiler-reports/IOBottleneck.json
# fraud_model/linear-learner-2021-07-08-18-15-26-697/rule-output/ProfilerReport-1625768126/profiler-output/profiler-reports/LoadBalancing.json
# fraud_model/linear-learner-2021-07-08-18-15-26-697/rule-output/ProfilerReport-1625768126/profiler-output/profiler-reports/LowGPUUtilization.json
# fraud_model/linear-learner-2021-07-08-18-15-26-697/rule-output/ProfilerReport-1625768126/profiler-output/profiler-reports/MaxInitializationTime.json
# fraud_model/linear-learner-2021-07-08-18-15-26-697/rule-output/ProfilerReport-1625768126/profiler-output/profiler-reports/OverallFrameworkMetrics.json
# fraud_model/linear-learner-2021-07-08-18-15-26-697/rule-output/ProfilerReport-1625768126/profiler-output/profiler-reports/OverallSystemUsage.json
# fraud_model/linear-learner-2021-07-08-18-15-26-697/rule-output/ProfilerReport-1625768126/profiler-output/profiler-reports/StepOutlier.json
# fraud_model/linear-learner-2021-07-08-20-44-52-964/output/model.tar.gz
# fraud_model/linear-learner-2021-07-08-20-44-52-964/profiler-output/framework/training_job_end.ts
# fraud_model/linear-learner-2021-07-08-20-44-52-964/profiler-output/system/incremental/2021070820/1625777220.algo-1.json
# fraud_model/linear-learner-2021-07-08-20-44-52-964/profiler-output/system/incremental/2021070820/1625777280.algo-1.json
# fraud_model/linear-learner-2021-07-08-20-44-52-964/profiler-output/system/incremental/2021070820/1625777340.algo-1.json
# fraud_model/linear-learner-2021-07-08-20-44-52-964/profiler-output/system/incremental/2021070820/1625777400.algo-1.json
# fraud_model/linear-learner-2021-07-08-20-44-52-964/profiler-output/system/training_job_end.ts
# fraud_model/linear-learner-2021-07-08-20-44-52-964/rule-output/ProfilerReport-1625777092/profiler-output/profiler-report.html
# fraud_model/linear-learner-2021-07-08-20-44-52-964/rule-output/ProfilerReport-1625777092/profiler-output/profiler-report.ipynb
# fraud_model/linear-learner-2021-07-08-20-44-52-964/rule-output/ProfilerReport-1625777092/profiler-output/profiler-reports/BatchSize.json
# fraud_model/linear-learner-2021-07-08-20-44-52-964/rule-output/ProfilerReport-1625777092/profiler-output/profiler-reports/CPUBottleneck.json
# fraud_model/linear-learner-2021-07-08-20-44-52-964/rule-output/ProfilerReport-1625777092/profiler-output/profiler-reports/Dataloader.json
# fraud_model/linear-learner-2021-07-08-20-44-52-964/rule-output/ProfilerReport-1625777092/profiler-output/profiler-reports/GPUMemoryIncrease.json
# fraud_model/linear-learner-2021-07-08-20-44-52-964/rule-output/ProfilerReport-1625777092/profiler-output/profiler-reports/IOBottleneck.json
# fraud_model/linear-learner-2021-07-08-20-44-52-964/rule-output/ProfilerReport-1625777092/profiler-output/profiler-reports/LoadBalancing.json
# fraud_model/linear-learner-2021-07-08-20-44-52-964/rule-output/ProfilerReport-1625777092/profiler-output/profiler-reports/LowGPUUtilization.json
# fraud_model/linear-learner-2021-07-08-20-44-52-964/rule-output/ProfilerReport-1625777092/profiler-output/profiler-reports/MaxInitializationTime.json
# fraud_model/linear-learner-2021-07-08-20-44-52-964/rule-output/ProfilerReport-1625777092/profiler-output/profiler-reports/OverallFrameworkMetrics.json
# fraud_model/linear-learner-2021-07-08-20-44-52-964/rule-output/ProfilerReport-1625777092/profiler-output/profiler-reports/OverallSystemUsage.json
# fraud_model/linear-learner-2021-07-08-20-44-52-964/rule-output/ProfilerReport-1625777092/profiler-output/profiler-reports/StepOutlier.json
# fraud_model/linear-learner-2021-07-08-21-49-28-086/output/model.tar.gz
# fraud_model/linear-learner-2021-07-08-21-49-28-086/profiler-output/framework/training_job_end.ts
# fraud_model/linear-learner-2021-07-08-21-49-28-086/profiler-output/system/incremental/2021070821/1625781120.algo-1.json
# fraud_model/linear-learner-2021-07-08-21-49-28-086/profiler-output/system/incremental/2021070821/1625781180.algo-1.json
# fraud_model/linear-learner-2021-07-08-21-49-28-086/profiler-output/system/incremental/2021070821/1625781240.algo-1.json
# fraud_model/linear-learner-2021-07-08-21-49-28-086/profiler-output/system/training_job_end.ts
# fraud_model/linear-learner-2021-07-08-21-49-28-086/rule-output/ProfilerReport-1625780968/profiler-output/profiler-report.html
# fraud_model/linear-learner-2021-07-08-21-49-28-086/rule-output/ProfilerReport-1625780968/profiler-output/profiler-report.ipynb
# fraud_model/linear-learner-2021-07-08-21-49-28-086/rule-output/ProfilerReport-1625780968/profiler-output/profiler-reports/BatchSize.json
# fraud_model/linear-learner-2021-07-08-21-49-28-086/rule-output/ProfilerReport-1625780968/profiler-output/profiler-reports/CPUBottleneck.json
# fraud_model/linear-learner-2021-07-08-21-49-28-086/rule-output/ProfilerReport-1625780968/profiler-output/profiler-reports/Dataloader.json
# fraud_model/linear-learner-2021-07-08-21-49-28-086/rule-output/ProfilerReport-1625780968/profiler-output/profiler-reports/GPUMemoryIncrease.json
# fraud_model/linear-learner-2021-07-08-21-49-28-086/rule-output/ProfilerReport-1625780968/profiler-output/profiler-reports/IOBottleneck.json
# fraud_model/linear-learner-2021-07-08-21-49-28-086/rule-output/ProfilerReport-1625780968/profiler-output/profiler-reports/LoadBalancing.json
# fraud_model/linear-learner-2021-07-08-21-49-28-086/rule-output/ProfilerReport-1625780968/profiler-output/profiler-reports/LowGPUUtilization.json
# fraud_model/linear-learner-2021-07-08-21-49-28-086/rule-output/ProfilerReport-1625780968/profiler-output/profiler-reports/MaxInitializationTime.json
# fraud_model/linear-learner-2021-07-08-21-49-28-086/rule-output/ProfilerReport-1625780968/profiler-output/profiler-reports/OverallFrameworkMetrics.json
# fraud_model/linear-learner-2021-07-08-21-49-28-086/rule-output/ProfilerReport-1625780968/profiler-output/profiler-reports/OverallSystemUsage.json
# fraud_model/linear-learner-2021-07-08-21-49-28-086/rule-output/ProfilerReport-1625780968/profiler-output/profiler-reports/StepOutlier.json
# fraud_model/linear-learner-2021-07-09-01-16-28-990/output/model.tar.gz
# fraud_model/linear-learner-2021-07-09-01-16-28-990/profiler-output/framework/training_job_end.ts
# fraud_model/linear-learner-2021-07-09-01-16-28-990/profiler-output/system/incremental/2021070901/1625793540.algo-1.json
# fraud_model/linear-learner-2021-07-09-01-16-28-990/profiler-output/system/incremental/2021070901/1625793600.algo-1.json
# fraud_model/linear-learner-2021-07-09-01-16-28-990/profiler-output/system/incremental/2021070901/1625793660.algo-1.json
# fraud_model/linear-learner-2021-07-09-01-16-28-990/profiler-output/system/training_job_end.ts
# fraud_model/linear-learner-2021-07-09-01-16-28-990/rule-output/ProfilerReport-1625793388/profiler-output/profiler-report.html
# fraud_model/linear-learner-2021-07-09-01-16-28-990/rule-output/ProfilerReport-1625793388/profiler-output/profiler-report.ipynb
# fraud_model/linear-learner-2021-07-09-01-16-28-990/rule-output/ProfilerReport-1625793388/profiler-output/profiler-reports/BatchSize.json
# fraud_model/linear-learner-2021-07-09-01-16-28-990/rule-output/ProfilerReport-1625793388/profiler-output/profiler-reports/CPUBottleneck.json
# fraud_model/linear-learner-2021-07-09-01-16-28-990/rule-output/ProfilerReport-1625793388/profiler-output/profiler-reports/Dataloader.json
# fraud_model/linear-learner-2021-07-09-01-16-28-990/rule-output/ProfilerReport-1625793388/profiler-output/profiler-reports/GPUMemoryIncrease.json
# fraud_model/linear-learner-2021-07-09-01-16-28-990/rule-output/ProfilerReport-1625793388/profiler-output/profiler-reports/IOBottleneck.json
# fraud_model/linear-learner-2021-07-09-01-16-28-990/rule-output/ProfilerReport-1625793388/profiler-output/profiler-reports/LoadBalancing.json
# fraud_model/linear-learner-2021-07-09-01-16-28-990/rule-output/ProfilerReport-1625793388/profiler-output/profiler-reports/LowGPUUtilization.json
# fraud_model/linear-learner-2021-07-09-01-16-28-990/rule-output/ProfilerReport-1625793388/profiler-output/profiler-reports/MaxInitializationTime.json
# fraud_model/linear-learner-2021-07-09-01-16-28-990/rule-output/ProfilerReport-1625793388/profiler-output/profiler-reports/OverallFrameworkMetrics.json
# fraud_model/linear-learner-2021-07-09-01-16-28-990/rule-output/ProfilerReport-1625793388/profiler-output/profiler-reports/OverallSystemUsage.json
# fraud_model/linear-learner-2021-07-09-01-16-28-990/rule-output/ProfilerReport-1625793388/profiler-output/profiler-reports/StepOutlier.json
# fraud_model/linear-learner-2021-07-09-01-50-25-453/output/model.tar.gz
# fraud_model/linear-learner-2021-07-09-01-50-25-453/profiler-output/framework/training_job_end.ts
# fraud_model/linear-learner-2021-07-09-01-50-25-453/profiler-output/system/incremental/2021070901/1625795580.algo-1.json
# fraud_model/linear-learner-2021-07-09-01-50-25-453/profiler-output/system/incremental/2021070901/1625795640.algo-1.json
# fraud_model/linear-learner-2021-07-09-01-50-25-453/profiler-output/system/incremental/2021070901/1625795700.algo-1.json
# fraud_model/linear-learner-2021-07-09-01-50-25-453/profiler-output/system/training_job_end.ts
# fraud_model/linear-learner-2021-07-09-01-50-25-453/rule-output/ProfilerReport-1625795425/profiler-output/profiler-report.html
# fraud_model/linear-learner-2021-07-09-01-50-25-453/rule-output/ProfilerReport-1625795425/profiler-output/profiler-report.ipynb
# fraud_model/linear-learner-2021-07-09-01-50-25-453/rule-output/ProfilerReport-1625795425/profiler-output/profiler-reports/BatchSize.json
# fraud_model/linear-learner-2021-07-09-01-50-25-453/rule-output/ProfilerReport-1625795425/profiler-output/profiler-reports/CPUBottleneck.json
# fraud_model/linear-learner-2021-07-09-01-50-25-453/rule-output/ProfilerReport-1625795425/profiler-output/profiler-reports/Dataloader.json
# fraud_model/linear-learner-2021-07-09-01-50-25-453/rule-output/ProfilerReport-1625795425/profiler-output/profiler-reports/GPUMemoryIncrease.json
# fraud_model/linear-learner-2021-07-09-01-50-25-453/rule-output/ProfilerReport-1625795425/profiler-output/profiler-reports/IOBottleneck.json
# fraud_model/linear-learner-2021-07-09-01-50-25-453/rule-output/ProfilerReport-1625795425/profiler-output/profiler-reports/LoadBalancing.json
# fraud_model/linear-learner-2021-07-09-01-50-25-453/rule-output/ProfilerReport-1625795425/profiler-output/profiler-reports/LowGPUUtilization.json
# fraud_model/linear-learner-2021-07-09-01-50-25-453/rule-output/ProfilerReport-1625795425/profiler-output/profiler-reports/MaxInitializationTime.json
# fraud_model/linear-learner-2021-07-09-01-50-25-453/rule-output/ProfilerReport-1625795425/profiler-output/profiler-reports/OverallFrameworkMetrics.json
# fraud_model/linear-learner-2021-07-09-01-50-25-453/rule-output/ProfilerReport-1625795425/profiler-output/profiler-reports/OverallSystemUsage.json
# fraud_model/linear-learner-2021-07-09-01-50-25-453/rule-output/ProfilerReport-1625795425/profiler-output/profiler-reports/StepOutlier.json
# plagiarism_exercise/test.csv
# plagiarism_exercise/train.csv
# sagemaker-pytorch-2021-07-02-00-13-36-512/source/sourcedir.tar.gz
# sagemaker-pytorch-2021-07-02-00-25-30-476/debug-output/training_job_end.ts
# sagemaker-pytorch-2021-07-02-00-25-30-476/output/model.tar.gz
# sagemaker-pytorch-2021-07-02-00-25-30-476/source/sourcedir.tar.gz
# sagemaker-pytorch-2021-07-02-00-26-14-331/source/sourcedir.tar.gz
# sagemaker-pytorch-2021-07-02-00-27-27-418/source/sourcedir.tar.gz
# sagemaker-pytorch-2021-07-02-00-31-16-108/source/sourcedir.tar.gz
# sagemaker-pytorch-2021-07-02-00-31-46-215/source/sourcedir.tar.gz
# sagemaker-pytorch-2021-07-02-00-32-46-189/source/sourcedir.tar.gz
# sagemaker-pytorch-2021-07-02-00-33-23-410/source/sourcedir.tar.gz
# sagemaker-pytorch-2021-07-02-00-33-48-938/debug-output/training_job_end.ts
# sagemaker-pytorch-2021-07-02-00-33-48-938/output/model.tar.gz
# sagemaker-pytorch-2021-07-02-00-33-48-938/source/sourcedir.tar.gz
# sagemaker-pytorch-2021-07-02-01-24-51-689/debug-output/training_job_end.ts
# sagemaker-pytorch-2021-07-02-01-24-51-689/output/model.tar.gz
# sagemaker-pytorch-2021-07-02-01-24-51-689/source/sourcedir.tar.gz
# sagemaker-pytorch-2021-07-02-01-28-25-614/debug-output/training_job_end.ts
# sagemaker-pytorch-2021-07-02-01-28-25-614/output/model.tar.gz
# sagemaker-pytorch-2021-07-02-01-28-25-614/source/sourcedir.tar.gz
# sagemaker-pytorch-2021-07-02-01-44-02-527/debug-output/training_job_end.ts
# sagemaker-pytorch-2021-07-02-01-44-02-527/output/model.tar.gz
# sagemaker-pytorch-2021-07-02-01-44-02-527/source/sourcedir.tar.gz
# sagemaker-pytorch-2021-07-02-02-17-43-374/debug-output/training_job_end.ts
# sagemaker-pytorch-2021-07-02-02-17-43-374/output/model.tar.gz
# sagemaker-pytorch-2021-07-02-02-17-43-374/source/sourcedir.tar.gz
# sagemaker-pytorch-2021-07-02-16-39-30-349/sourcedir.tar.gz
# sagemaker-pytorch-2021-07-03-02-24-57-144/debug-output/training_job_end.ts
# sagemaker-pytorch-2021-07-03-02-24-57-144/output/model.tar.gz
# sagemaker-pytorch-2021-07-03-02-24-57-144/source/sourcedir.tar.gz
# sagemaker-pytorch-2021-07-13-17-56-19-975/source/sourcedir.tar.gz
# sagemaker-pytorch-2021-07-13-18-01-11-685/source/sourcedir.tar.gz
# sagemaker-pytorch-2021-07-13-18-19-43-227/source/sourcedir.tar.gz
# sagemaker-pytorch-2021-07-13-18-23-25-992/source/sourcedir.tar.gz
# sagemaker-pytorch-2021-07-13-18-40-08-871/source/sourcedir.tar.gz
# sagemaker-pytorch-2021-07-13-19-23-26-321/source/sourcedir.tar.gz
# sagemaker-pytorch-2021-07-13-19-36-24-837/source/sourcedir.tar.gz
# sagemaker-pytorch-2021-07-13-19-42-27-134/sourcedir.tar.gz
# sagemaker-record-sets/KMeans-2021-07-07-20-52-04-984/.amazon.manifest
# sagemaker-record-sets/KMeans-2021-07-07-20-52-04-984/matrix_0.pbr
# sagemaker-record-sets/KMeans-2021-07-07-20-52-19-421/.amazon.manifest
# sagemaker-record-sets/KMeans-2021-07-07-20-52-19-421/matrix_0.pbr
# sagemaker-record-sets/KMeans-2021-07-07-20-52-26-540/.amazon.manifest
# sagemaker-record-sets/KMeans-2021-07-07-20-52-26-540/matrix_0.pbr
# sagemaker-record-sets/KMeans-2021-07-07-20-52-44-374/.amazon.manifest
# sagemaker-record-sets/KMeans-2021-07-07-20-52-44-374/matrix_0.pbr
# sagemaker-record-sets/KMeans-2021-07-07-20-52-56-820/.amazon.manifest
# sagemaker-record-sets/KMeans-2021-07-07-20-52-56-820/matrix_0.pbr
# sagemaker-record-sets/KMeans-2021-07-07-20-53-11-654/.amazon.manifest
# sagemaker-record-sets/KMeans-2021-07-07-20-53-11-654/matrix_0.pbr
# sagemaker-record-sets/KMeans-2021-07-07-20-53-58-429/.amazon.manifest
# sagemaker-record-sets/KMeans-2021-07-07-20-53-58-429/matrix_0.pbr
# sagemaker-record-sets/KMeans-2021-07-07-20-54-09-017/.amazon.manifest
# sagemaker-record-sets/KMeans-2021-07-07-20-54-09-017/matrix_0.pbr
# sagemaker-record-sets/LinearLearner-2021-07-08-18-03-01-757/.amazon.manifest
# sagemaker-record-sets/LinearLearner-2021-07-08-18-03-01-757/matrix_0.pbr
# sagemaker-record-sets/LinearLearner-2021-07-08-18-03-34-972/.amazon.manifest
# sagemaker-record-sets/LinearLearner-2021-07-08-18-03-34-972/matrix_0.pbr
# sagemaker-record-sets/LinearLearner-2021-07-08-18-04-26-573/.amazon.manifest
# sagemaker-record-sets/LinearLearner-2021-07-08-18-04-26-573/matrix_0.pbr
# sagemaker-record-sets/LinearLearner-2021-07-08-18-15-18-776/.amazon.manifest
# sagemaker-record-sets/LinearLearner-2021-07-08-18-15-18-776/matrix_0.pbr
# sagemaker-record-sets/LinearLearner-2021-07-08-20-44-46-257/.amazon.manifest
# sagemaker-record-sets/LinearLearner-2021-07-08-20-44-46-257/matrix_0.pbr
# sagemaker-record-sets/LinearLearner-2021-07-08-21-10-29-012/.amazon.manifest
# sagemaker-record-sets/LinearLearner-2021-07-08-21-10-29-012/matrix_0.pbr
# sagemaker-record-sets/LinearLearner-2021-07-08-21-23-16-539/.amazon.manifest
# sagemaker-record-sets/LinearLearner-2021-07-08-21-23-16-539/matrix_0.pbr
# sagemaker-record-sets/LinearLearner-2021-07-09-01-16-24-012/.amazon.manifest
# sagemaker-record-sets/LinearLearner-2021-07-09-01-16-24-012/matrix_0.pbr
# sagemaker-record-sets/LinearLearner-2021-07-09-01-50-17-268/.amazon.manifest
# sagemaker-record-sets/LinearLearner-2021-07-09-01-50-17-268/matrix_0.pbr
# sagemaker-record-sets/LinearLearner-2021-07-09-02-14-40-686/.amazon.manifest
# sagemaker-record-sets/LinearLearner-2021-07-09-02-14-40-686/matrix_0.pbr
# sagemaker-record-sets/LinearLearner-2021-07-09-21-50-34-083/.amazon.manifest
# sagemaker-record-sets/LinearLearner-2021-07-09-21-50-34-083/matrix_0.pbr
# sagemaker-record-sets/PCA-2021-07-05-20-12-31-560/.amazon.manifest
# sagemaker-record-sets/PCA-2021-07-05-20-12-31-560/matrix_0.pbr
# sagemaker-record-sets/PCA-2021-07-05-20-17-48-148/.amazon.manifest
# sagemaker-record-sets/PCA-2021-07-05-20-17-48-148/matrix_0.pbr
# sagemaker-record-sets/PCA-2021-07-05-21-11-15-255/.amazon.manifest
# sagemaker-record-sets/PCA-2021-07-05-21-11-15-255/matrix_0.pbr
# sagemaker-record-sets/PCA-2021-07-06-00-19-36-059/.amazon.manifest
# sagemaker-record-sets/PCA-2021-07-06-00-19-36-059/matrix_0.pbr
# sagemaker-record-sets/PCA-2021-07-06-01-02-47-339/.amazon.manifest
# sagemaker-record-sets/PCA-2021-07-06-01-02-47-339/matrix_0.pbr
# sagemaker-record-sets/PCA-2021-07-07-15-52-58-070/.amazon.manifest
# sagemaker-record-sets/PCA-2021-07-07-15-52-58-070/matrix_0.pbr
# sagemaker/moon-data/sagemaker-pytorch-2021-07-13-18-23-25-992/output/model.tar.gz
# sagemaker/moon-data/sagemaker-pytorch-2021-07-13-18-40-08-871/output/model.tar.gz
# sagemaker/moon-data/sagemaker-pytorch-2021-07-13-19-23-26-321/output/model.tar.gz
# sagemaker/moon-data/sagemaker-pytorch-2021-07-13-19-36-24-837/debug-output/training_job_end.ts
# sagemaker/moon-data/sagemaker-pytorch-2021-07-13-19-36-24-837/output/model.tar.gz
# sagemaker/moon-data/train.csv
# sagemaker/sentiment_rnn/train.csv
# sagemaker/sentiment_rnn/word_dict.pkl
# sentiment-web-app/output/xgboost-2021-06-30-17-57-14-832/output/model.tar.gz
# sentiment-web-app/output/xgboost-2021-06-30-18-59-58-091/output/model.tar.gz
# sentiment-web-app/output/xgboost-2021-07-01-18-32-29-932/output/model.tar.gz
# sentiment-web-app/test.csv
# sentiment-web-app/train.csv
# sentiment-web-app/validation.csv
# sentiment-xgboost/output/xgboost-2021-06-29-20-56-43-380/output/model.tar.gz
# sentiment-xgboost/output/xgboost-2021-06-30-03-20-05-204/output/model.tar.gz
# sentiment-xgboost/test.csv
# sentiment-xgboost/train.csv
# sentiment-xgboost/validation.csv
# time-series-energy-data/forecasting-deepar-2021-07-19-16-55-20-994/output/model.tar.gz
# time-series-energy-data/forecasting-deepar-2021-07-19-16-55-20-994/profiler-output/framework/training_job_end.ts
# time-series-energy-data/forecasting-deepar-2021-07-19-16-55-20-994/profiler-output/system/incremental/2021071916/1626713880.algo-1.json
# time-series-energy-data/forecasting-deepar-2021-07-19-16-55-20-994/profiler-output/system/incremental/2021071916/1626713940.algo-1.json
# time-series-energy-data/forecasting-deepar-2021-07-19-16-55-20-994/profiler-output/system/incremental/2021071917/1626714000.algo-1.json
# time-series-energy-data/forecasting-deepar-2021-07-19-16-55-20-994/profiler-output/system/incremental/2021071917/1626714060.algo-1.json
# time-series-energy-data/forecasting-deepar-2021-07-19-16-55-20-994/profiler-output/system/training_job_end.ts
# time-series-energy-data/forecasting-deepar-2021-07-19-16-55-20-994/rule-output/ProfilerReport-1626713720/profiler-output/profiler-report.html
# time-series-energy-data/forecasting-deepar-2021-07-19-16-55-20-994/rule-output/ProfilerReport-1626713720/profiler-output/profiler-report.ipynb
# time-series-energy-data/forecasting-deepar-2021-07-19-16-55-20-994/rule-output/ProfilerReport-1626713720/profiler-output/profiler-reports/BatchSize.json
# time-series-energy-data/forecasting-deepar-2021-07-19-16-55-20-994/rule-output/ProfilerReport-1626713720/profiler-output/profiler-reports/CPUBottleneck.json
# time-series-energy-data/forecasting-deepar-2021-07-19-16-55-20-994/rule-output/ProfilerReport-1626713720/profiler-output/profiler-reports/Dataloader.json
# time-series-energy-data/forecasting-deepar-2021-07-19-16-55-20-994/rule-output/ProfilerReport-1626713720/profiler-output/profiler-reports/GPUMemoryIncrease.json
# time-series-energy-data/forecasting-deepar-2021-07-19-16-55-20-994/rule-output/ProfilerReport-1626713720/profiler-output/profiler-reports/IOBottleneck.json
# time-series-energy-data/forecasting-deepar-2021-07-19-16-55-20-994/rule-output/ProfilerReport-1626713720/profiler-output/profiler-reports/LoadBalancing.json
# time-series-energy-data/forecasting-deepar-2021-07-19-16-55-20-994/rule-output/ProfilerReport-1626713720/profiler-output/profiler-reports/LowGPUUtilization.json
# time-series-energy-data/forecasting-deepar-2021-07-19-16-55-20-994/rule-output/ProfilerReport-1626713720/profiler-output/profiler-reports/MaxInitializationTime.json
# time-series-energy-data/forecasting-deepar-2021-07-19-16-55-20-994/rule-output/ProfilerReport-1626713720/profiler-output/profiler-reports/OverallFrameworkMetrics.json
# time-series-energy-data/forecasting-deepar-2021-07-19-16-55-20-994/rule-output/ProfilerReport-1626713720/profiler-output/profiler-reports/OverallSystemUsage.json
# time-series-energy-data/forecasting-deepar-2021-07-19-16-55-20-994/rule-output/ProfilerReport-1626713720/profiler-output/profiler-reports/StepOutlier.json
# time-series-energy-data/forecasting-deepar-2021-07-19-16-56-04-425/output/model.tar.gz
# time-series-energy-data/forecasting-deepar-2021-07-19-16-56-04-425/profiler-output/framework/training_job_end.ts
# time-series-energy-data/forecasting-deepar-2021-07-19-16-56-04-425/profiler-output/system/incremental/2021071916/1626713880.algo-1.json
# time-series-energy-data/forecasting-deepar-2021-07-19-16-56-04-425/profiler-output/system/incremental/2021071916/1626713940.algo-1.json
# time-series-energy-data/forecasting-deepar-2021-07-19-16-56-04-425/profiler-output/system/incremental/2021071917/1626714000.algo-1.json
# time-series-energy-data/forecasting-deepar-2021-07-19-16-56-04-425/profiler-output/system/incremental/2021071917/1626714060.algo-1.json
# time-series-energy-data/forecasting-deepar-2021-07-19-16-56-04-425/profiler-output/system/training_job_end.ts
# time-series-energy-data/forecasting-deepar-2021-07-19-16-56-04-425/rule-output/ProfilerReport-1626713764/profiler-output/profiler-report.html
# time-series-energy-data/forecasting-deepar-2021-07-19-16-56-04-425/rule-output/ProfilerReport-1626713764/profiler-output/profiler-report.ipynb
# time-series-energy-data/forecasting-deepar-2021-07-19-16-56-04-425/rule-output/ProfilerReport-1626713764/profiler-output/profiler-reports/BatchSize.json
# time-series-energy-data/forecasting-deepar-2021-07-19-16-56-04-425/rule-output/ProfilerReport-1626713764/profiler-output/profiler-reports/CPUBottleneck.json
# time-series-energy-data/forecasting-deepar-2021-07-19-16-56-04-425/rule-output/ProfilerReport-1626713764/profiler-output/profiler-reports/Dataloader.json
# time-series-energy-data/forecasting-deepar-2021-07-19-16-56-04-425/rule-output/ProfilerReport-1626713764/profiler-output/profiler-reports/GPUMemoryIncrease.json
# time-series-energy-data/forecasting-deepar-2021-07-19-16-56-04-425/rule-output/ProfilerReport-1626713764/profiler-output/profiler-reports/IOBottleneck.json
# time-series-energy-data/forecasting-deepar-2021-07-19-16-56-04-425/rule-output/ProfilerReport-1626713764/profiler-output/profiler-reports/LoadBalancing.json
# time-series-energy-data/forecasting-deepar-2021-07-19-16-56-04-425/rule-output/ProfilerReport-1626713764/profiler-output/profiler-reports/LowGPUUtilization.json
# time-series-energy-data/forecasting-deepar-2021-07-19-16-56-04-425/rule-output/ProfilerReport-1626713764/profiler-output/profiler-reports/MaxInitializationTime.json
# time-series-energy-data/forecasting-deepar-2021-07-19-16-56-04-425/rule-output/ProfilerReport-1626713764/profiler-output/profiler-reports/OverallFrameworkMetrics.json
# time-series-energy-data/forecasting-deepar-2021-07-19-16-56-04-425/rule-output/ProfilerReport-1626713764/profiler-output/profiler-reports/OverallSystemUsage.json
# time-series-energy-data/forecasting-deepar-2021-07-19-16-56-04-425/rule-output/ProfilerReport-1626713764/profiler-output/profiler-reports/StepOutlier.json
# time-series-energy-data/forecasting-deepar-2021-07-19-17-54-53-344/output/model.tar.gz
# time-series-energy-data/test.json
# time-series-energy-data/test/test.json
# time-series-energy-data/train.json
# time-series-energy-data/train/train.json
# xgboost-2021-06-29-16-22-11-386/test.csv.out
# xgboost-2021-06-30-03-28-51-132/test.csv.out
# xgboost-2021-06-30-18-13-39-565/test.csv.out
# xgboost-2021-06-30-19-09-45-576/test.csv.out
# xgboost-2021-07-01-18-41-46-242/test.csv.out
# Test passed!

# %% [markdown]
# ---
#
# # Modeling
#
# Now that you've uploaded your training data, it's time to define and train a model!
#
# The type of model you create is up to you. For a binary classification task, you can choose to go one of three routes:
# * Use a built-in classification algorithm, like LinearLearner.
# * Define a custom Scikit-learn classifier, a comparison of models can be found [here](https://scikit-learn.org/stable/auto_examples/classification/plot_classifier_comparison.html).
# * Define a custom PyTorch neural network classifier.
#
# It will be up to you to test out a variety of models and choose the best one. Your project will be graded on the accuracy of your final model.
#
# ---
#
# ## EXERCISE: Complete a training script
#
# To implement a custom classifier, you'll need to complete a `train.py` script. You've been given the folders `source_sklearn` and `source_pytorch` which hold starting code for a custom Scikit-learn model and a PyTorch model, respectively. Each directory has a `train.py` training script. To complete this project **you only need to complete one of these scripts**; the script that is responsible for training your final model.
#
# A typical training script:
# * Loads training data from a specified directory
# * Parses any training & model hyperparameters (ex. nodes in a neural network, training epochs, etc.)
# * Instantiates a model of your design, with any specified hyperparams
# * Trains that model
# * Finally, saves the model so that it can be hosted/deployed, later
#
# ### Defining and training a model
# Much of the training script code is provided for you. Almost all of your work will be done in the `if __name__ == '__main__':` section. To complete a `train.py` file, you will:
# 1. Import any extra libraries you need
# 2. Define any additional model training hyperparameters using `parser.add_argument`
# 2. Define a model in the `if __name__ == '__main__':` section
# 3. Train the model in that same section
#
# Below, you can use `!pygmentize` to display an existing `train.py` file. Read through the code; all of your tasks are marked with `TODO` comments.
#
# **Note: If you choose to create a custom PyTorch model, you will be responsible for defining the model in the `model.py` file,** and a `predict.py` file is provided. If you choose to use Scikit-learn, you only need a `train.py` file; you may import a classifier from the `sklearn` library.

# %% [raw]
# # directory can be changed to: source_sklearn or source_pytorch
# !pygmentize source_sklearn/train.py

# %% [markdown]
# ### Provided code
#
# If you read the code above, you can see that the starter code includes a few things:
# * Model loading (`model_fn`) and saving code
# * Getting SageMaker's default hyperparameters
# * Loading the training data by name, `train.csv` and extracting the features and labels, `train_x`, and `train_y`
#
# If you'd like to read more about model saving with [joblib for sklearn](https://scikit-learn.org/stable/modules/model_persistence.html) or with [torch.save](https://pytorch.org/tutorials/beginner/saving_loading_models.html), click on the provided links.

# %% [markdown]
# ---
# # Create an Estimator
#
# When a custom model is constructed in SageMaker, an entry point must be specified. This is the Python file which will be executed when the model is trained; the `train.py` function you specified above. To run a custom training script in SageMaker, construct an estimator, and fill in the appropriate constructor arguments:
#
# * **entry_point**: The path to the Python script SageMaker runs for training and prediction.
# * **source_dir**: The path to the training script directory `source_sklearn` OR `source_pytorch`.
# * **role**: Role ARN, which was specified, above.
# * **train_instance_count**: The number of training instances (should be left at 1).
# * **train_instance_type**: The type of SageMaker instance for training. Note: Because Scikit-learn does not natively support GPU training, Sagemaker Scikit-learn does not currently support training on GPU instance types.
# * **sagemaker_session**: The session used to train on Sagemaker.
# * **hyperparameters** (optional): A dictionary `{'name':value, ..}` passed to the train function as hyperparameters.
#
# Note: For a PyTorch model, there is another optional argument **framework_version**, which you can set to the latest version of PyTorch, `1.0`.
#
# ## EXERCISE: Define a Scikit-learn or PyTorch estimator
#
# To import your desired estimator, use one of the following lines:
# ```
# from sagemaker.sklearn.estimator import SKLearn
# ```
# ```
# from sagemaker.pytorch import PyTorch
# ```

# %%
# your import and estimator code, here

# specify an output path
# prefix is specified above
output_path = 's3://{}/{}'.format(bucket, prefix)

# instantiate a pytorch estimator
estimator = PyTorch(entry_point='train.py',
                    source_dir='source_pytorch', # this should be just "source" for your code
                    role=role,
                    framework_version='1.0',
                    train_instance_count=1,
                    train_instance_type='ml.c4.xlarge',
                    output_path=output_path,
                    sagemaker_session=sagemaker_session,
                    hyperparameters={
                        'input_dim': 4,  # num of features
                        'hidden_dim': 12,
                        'output_dim': 1,
                        'epochs': 30 # could change to higher
                    })

# %% [markdown]
# ## EXERCISE: Train the estimator
#
# Train your estimator on the training data stored in S3. This should create a training job that you can monitor in your SageMaker console.

# %%
# %%time

# Train your estimator on S3 training data

# %% [markdown]
# ## EXERCISE: Deploy the trained model
#
# After training, deploy your model to create a `predictor`. If you're using a PyTorch model, you'll need to create a trained `PyTorchModel` that accepts the trained `<model>.model_data` as an input parameter and points to the provided `source_pytorch/predict.py` file as an entry point.
#
# To deploy a trained model, you'll use `<model>.deploy`, which takes in two arguments:
# * **initial_instance_count**: The number of deployed instances (1).
# * **instance_type**: The type of SageMaker instance for deployment.
#
# Note: If you run into an instance error, it may be because you chose the wrong training or deployment instance_type. It may help to refer to your previous exercise code to see which types of instances we used.

# %%
# %%time

# uncomment, if needed
# from sagemaker.pytorch import PyTorchModel


# deploy your model to create a predictor
predictor = None

# %% [markdown]
# ---
# # Evaluating Your Model
#
# Once your model is deployed, you can see how it performs when applied to our test data.
#
# The provided cell below, reads in the test data, assuming it is stored locally in `data_dir` and named `test.csv`. The labels and features are extracted from the `.csv` file.

# %%
"""
DON'T MODIFY ANYTHING IN THIS CELL THAT IS BELOW THIS LINE
"""
import os

# read in test data, assuming it is stored locally
test_data = pd.read_csv(os.path.join(data_dir, "test.csv"), header=None, names=None)

# labels are in the first column
test_y = test_data.iloc[:,0]
test_x = test_data.iloc[:,1:]

# %% [markdown]
# ## EXERCISE: Determine the accuracy of your model
#
# Use your deployed `predictor` to generate predicted, class labels for the test data. Compare those to the *true* labels, `test_y`, and calculate the accuracy as a value between 0 and 1.0 that indicates the fraction of test data that your model classified correctly. You may use [sklearn.metrics](https://scikit-learn.org/stable/modules/classes.html#module-sklearn.metrics) for this calculation.
#
# **To pass this project, your model should get at least 90% test accuracy.**

# %%
# First: generate predicted, class labels
test_y_preds = None


"""
DON'T MODIFY ANYTHING IN THIS CELL THAT IS BELOW THIS LINE
"""
# test that your model generates the correct number of labels
assert len(test_y_preds)==len(test_y), 'Unexpected number of predictions.'
print('Test passed!')

# %%
# Second: calculate the test accuracy
accuracy = None

print(accuracy)


## print out the array of predicted and true labels, if you want
print('\nPredicted class labels: ')
print(test_y_preds)
print('\nTrue class labels: ')
print(test_y.values)

# %% [markdown]
# ### Question 1: How many false positives and false negatives did your model produce, if any? And why do you think this is?

# %% [markdown]
# ** Answer**:

# %% [markdown]
# ### Question 2: How did you decide on the type of model to use?

# %% [markdown]
# ** Answer**:

# %% [markdown]
# ----
# ## EXERCISE: Clean up Resources
#
# After you're done evaluating your model, **delete your model endpoint**. You can do this with a call to `.delete_endpoint()`. You need to show, in this notebook, that the endpoint was deleted. Any other resources, you may delete from the AWS console, and you will find more instructions on cleaning up all your resources, below.

# %%
# uncomment and fill in the line below!
# <name_of_deployed_predictor>.delete_endpoint()

# %% [markdown]
# ### Deleting S3 bucket
#
# When you are *completely* done with training and testing models, you can also delete your entire S3 bucket. If you do this before you are done training your model, you'll have to recreate your S3 bucket and upload your training data again.

# %%
# deleting bucket, uncomment lines below

# bucket_to_delete = boto3.resource('s3').Bucket(bucket)
# bucket_to_delete.objects.all().delete()

# %% [markdown]
# ### Deleting all your models and instances
#
# When you are _completely_ done with this project and do **not** ever want to revisit this notebook, you can choose to delete all of your SageMaker notebook instances and models by following [these instructions](https://docs.aws.amazon.com/sagemaker/latest/dg/ex1-cleanup.html). Before you delete this notebook instance, I recommend at least downloading a copy and saving it, locally.

# %% [markdown]
# ---
# ## Further Directions
#
# There are many ways to improve or add on to this project to expand your learning or make this more of a unique project for you. A few ideas are listed below:
# * Train a classifier to predict the *category* (1-3) of plagiarism and not just plagiarized (1) or not (0).
# * Utilize a different and larger dataset to see if this model can be extended to other types of plagiarism.
# * Use language or character-level analysis to find different (and more) similarity features.
# * Write a complete pipeline function that accepts a source text and submitted text file, and classifies the submitted text as plagiarized or not.
# * Use API Gateway and a lambda function to deploy your model to a web application.
#
# These are all just options for extending your work. If you've completed all the exercises in this notebook, you've completed a real-world application, and can proceed to submit your project. Great job!
